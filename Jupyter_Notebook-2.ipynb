# %% [markdown]
# <center>
#     <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/Logos/organization_logo/organization_logo.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# __Claire B__
#
# Student

# %% [markdown]
# _I am interested in Data Science because it has become a must in the world we live in._

# %% [markdown]
# ### The following formula gives the area of a square :

# %%
def square_area(a):
    return a*a
square_area (4)
# Out:
# 16

# %% [markdown]
# > “The most interesting types of data are those collected for one purpose and used for another.” — Erin Shellman

# %% [markdown]
# ![800px-Jupyter_logo.svg.png](attachment:543ba95e-eebb-4d45-b679-6c484a86b29e.png)

# %% [markdown]
# - red
# - blue
# - yellow
